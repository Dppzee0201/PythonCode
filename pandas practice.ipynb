# %%
pwd
# Out:
# 'C:\\Users\\Dppzee'

# %%
import pandas as pd

# %%
df = pd.read_csv("D:\Python code\CSV\heart_disease.csv")

# %%
df
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
df.head(50)
# Out:
#      Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0   56.0    Male           153.0              155.0            High     Yes
# 1   69.0  Female           146.0              286.0            High      No
# 2   46.0    Male           126.0              216.0             Low      No
# 3   32.0  Female           122.0              293.0            High     Yes
# 4   60.0    Male           166.0              242.0             Low     Yes
# 5   25.0    Male           152.0              257.0             Low     Yes
# 6   78.0  Female           121.0              175.0            High     Yes
# 7   38.0  Female           161.0              187.0             Low     Yes
# 8   56.0  Female           135.0              291.0             Low      No
# 9   75.0    Male           144.0              252.0             Low     Yes
# 10  36.0  Female           179.0              191.0            High      No
# ...

# %%
df.head(100).tail(50)
# Out:
#      Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 50  68.0    Male           176.0              270.0             Low      No
# 51  61.0  Female           173.0              158.0             Low      No
# 52  72.0  Female           139.0              283.0             Low     Yes
# 53  69.0  Female           141.0              272.0            High     Yes
# 54  74.0  Female           166.0              198.0          Medium      No
# 55  20.0  Female           171.0              240.0          Medium     Yes
# 56  54.0  Female           142.0              274.0            High     Yes
# 57  68.0    Male           160.0              225.0          Medium      No
# 58  24.0  Female           154.0              299.0            High     Yes
# 59  38.0  Female           122.0              253.0          Medium     Yes
# 60  26.0    Male           153.0              298.0            High     Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       56.0
# 1       69.0
# 2       46.0
# 3       32.0
# 4       60.0
#         ...
# 9995    25.0
# 9996    38.0
# 9997    73.0
# 9998    23.0
# 9999    38.0
# Name: Age, Length: 10000, dtype: float64

# %%
df.select_dtypes('float')
# Out:
#        Age  Blood Pressure  Cholesterol Level        BMI  Sleep Hours  \
# 0     56.0           153.0              155.0  24.991591     7.633228
# 1     69.0           146.0              286.0  25.221799     8.744034
# 2     46.0           126.0              216.0  29.855447     4.440440
# 3     32.0           122.0              293.0  24.130477     5.249405
# 4     60.0           166.0              242.0  20.486289     7.030971
# ...    ...             ...                ...        ...          ...
# 9995  25.0           136.0              243.0  18.788791     6.834954
# 9996  38.0           172.0              154.0  31.856801     8.247784
# 9997  73.0           152.0              201.0  26.899911     4.436762
# 9998  23.0           142.0              299.0  34.964026     8.526329
# 9999  38.0           128.0              193.0  25.111295     5.659394
#
#       Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
def con_int(x):
    return int(x)

# %%
temp = df.select_dtypes('float')

# %%
temp.applymap(con_int)
# Out:
# C:\Users\Dppzee\AppData\Local\Temp\ipykernel_4972\199074381.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   temp.applymap(con_int)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 temp.applymap(con_int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10174, in DataFrame.applymap(self, func, na_action, **kwargs)
#   10125 """
#   10126 Apply a function to a Dataframe elementwise.
#   10127
#    (...)
#   10167 1  5  5
#   10168 """
#   10169 warnings.warn(
#   10170     "DataFrame.applymap has been deprecated. Use DataFrame.map instead.",
#   10171     FutureWarning,
#   10172     stacklevel=find_stack_level(),
#   10173 )
# > 10174 return self.map(func, na_action=na_action, **kwargs)
#
# ...

# %%
temp
# Out:
#        Age  Blood Pressure  Cholesterol Level        BMI  Sleep Hours  \
# 0     56.0           153.0              155.0  24.991591     7.633228
# 1     69.0           146.0              286.0  25.221799     8.744034
# 2     46.0           126.0              216.0  29.855447     4.440440
# 3     32.0           122.0              293.0  24.130477     5.249405
# 4     60.0           166.0              242.0  20.486289     7.030971
# ...    ...             ...                ...        ...          ...
# 9995  25.0           136.0              243.0  18.788791     6.834954
# 9996  38.0           172.0              154.0  31.856801     8.247784
# 9997  73.0           152.0              201.0  26.899911     4.436762
# 9998  23.0           142.0              299.0  34.964026     8.526329
# 9999  38.0           128.0              193.0  25.111295     5.659394
#
#       Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level
# ...

# %%
temp.dropna(inplace=True)

# %%
temp
# Out:
#        Age  Blood Pressure  Cholesterol Level        BMI  Sleep Hours  \
# 1     69.0           146.0              286.0  25.221799     8.744034
# 2     46.0           126.0              216.0  29.855447     4.440440
# 3     32.0           122.0              293.0  24.130477     5.249405
# 4     60.0           166.0              242.0  20.486289     7.030971
# 5     25.0           152.0              257.0  28.144681     5.504876
# ...    ...             ...                ...        ...          ...
# 9995  25.0           136.0              243.0  18.788791     6.834954
# 9996  38.0           172.0              154.0  31.856801     8.247784
# 9997  73.0           152.0              201.0  26.899911     4.436762
# 9998  23.0           142.0              299.0  34.964026     8.526329
# 9999  38.0           128.0              193.0  25.111295     5.659394
#
#       Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level
# ...

# %%
def minus(element):
    return element-2

# %%
temp['Age'].apply(minus)
# Out:
# 1       67.0
# 2       44.0
# 3       30.0
# 4       58.0
# 5       23.0
#         ...
# 9995    23.0
# 9996    36.0
# 9997    71.0
# 9998    21.0
# 9999    36.0
# Name: Age, Length: 9781, dtype: float64

# %%
df.select_dtypes('O')
# Out:
#       Gender Exercise Habits Smoking Family Heart Disease Diabetes  \
# 0       Male            High     Yes                  Yes       No
# 1     Female            High      No                  Yes      Yes
# 2       Male             Low      No                   No       No
# 3     Female            High     Yes                  Yes       No
# 4       Male             Low     Yes                  Yes      Yes
# ...      ...             ...     ...                  ...      ...
# 9995  Female          Medium     Yes                   No       No
# 9996    Male          Medium      No                   No       No
# 9997    Male            High     Yes                   No      Yes
# 9998    Male             Low     Yes                   No      Yes
# 9999  Female          Medium     Yes                  Yes      Yes
#
#      High Blood Pressure Low HDL Cholesterol High LDL Cholesterol  \
# 0                    Yes                 Yes                   No
# ...

# %%
df['Gender_updated']=df['Gender'].map({'Male':0,'Female':1})

# %%
df
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
temp.drop(columns=['Age', 'Blood Pressure'])
# Out:
#       Cholesterol Level        BMI  Sleep Hours  Triglyceride Level  \
# 1                 286.0  25.221799     8.744034               133.0
# 2                 216.0  29.855447     4.440440               393.0
# 3                 293.0  24.130477     5.249405               293.0
# 4                 242.0  20.486289     7.030971               263.0
# 5                 257.0  28.144681     5.504876               126.0
# ...                 ...        ...          ...                 ...
# 9995              243.0  18.788791     6.834954               343.0
# 9996              154.0  31.856801     8.247784               377.0
# 9997              201.0  26.899911     4.436762               248.0
# 9998              299.0  34.964026     8.526329               113.0
# 9999              193.0  25.111295     5.659394               121.0
#
#       Fasting Blood Sugar  CRP Level  Homocysteine Level
# 1                   157.0   9.355389           19.298875
# ...

# %%
temp
# Out:
#        Age  Blood Pressure  Cholesterol Level        BMI  Sleep Hours  \
# 1     69.0           146.0              286.0  25.221799     8.744034
# 2     46.0           126.0              216.0  29.855447     4.440440
# 3     32.0           122.0              293.0  24.130477     5.249405
# 4     60.0           166.0              242.0  20.486289     7.030971
# 5     25.0           152.0              257.0  28.144681     5.504876
# ...    ...             ...                ...        ...          ...
# 9995  25.0           136.0              243.0  18.788791     6.834954
# 9996  38.0           172.0              154.0  31.856801     8.247784
# 9997  73.0           152.0              201.0  26.899911     4.436762
# 9998  23.0           142.0              299.0  34.964026     8.526329
# 9999  38.0           128.0              193.0  25.111295     5.659394
#
#       Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status',
#        'Gender_updated'],
#       dtype='object')

# %%
df.drop([2,3,4,5],inplace=True)

# %%
df
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 6     78.0  Female           121.0              175.0            High     Yes
# 7     38.0  Female           161.0              187.0             Low     Yes
# 8     56.0  Female           135.0              291.0             Low      No
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
df.sort_values('Age',ascending=True)
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 3236  18.0  Female           153.0              253.0             Low     Yes
# 3723  18.0  Female           152.0              265.0            High     Yes
# 5633  18.0  Female           150.0              281.0            High     Yes
# 5619  18.0  Female           163.0              265.0          Medium     Yes
# 5617  18.0  Female           141.0              299.0          Medium      No
# ...    ...     ...             ...                ...             ...     ...
# 7781   NaN    Male           170.0              297.0            High     Yes
# 8096   NaN  Female           167.0              255.0             Low     Yes
# 9192   NaN    Male           153.0              234.0            High     Yes
# 9268   NaN  Female           139.0              184.0            High      No
# 9835   NaN  Female           176.0              230.0             Low     Yes
#
# ...

# %%
df.reset_index()
# Out:
#       index   Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits  \
# 0         0  56.0    Male           153.0              155.0            High
# 1         1  69.0  Female           146.0              286.0            High
# 2         6  78.0  Female           121.0              175.0            High
# 3         7  38.0  Female           161.0              187.0             Low
# 4         8  56.0  Female           135.0              291.0             Low
# ...     ...   ...     ...             ...                ...             ...
# 9991   9995  25.0  Female           136.0              243.0          Medium
# 9992   9996  38.0    Male           172.0              154.0          Medium
# 9993   9997  73.0    Male           152.0              201.0            High
# 9994   9998  23.0    Male           142.0              299.0             Low
# 9995   9999  38.0  Female           128.0              193.0          Medium
#
# ...

# %%
df
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 6     78.0  Female           121.0              175.0            High     Yes
# 7     38.0  Female           161.0              187.0             Low     Yes
# 8     56.0  Female           135.0              291.0             Low      No
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...
